# %%
t1=()

# %%
t2=(1,)

# %%
t3=(1,2,3)

# %%
t4=1,2,3

# %%
t5=('a','b',('ab','cd'))

# %%
del t1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-0c1d4ae62391> in <module>()
# ----> 1 del t1[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
t[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-d0a24a012877> in <module>()
# ----> 1 t[0]
#
# NameError: name 't' is not defined

# %%
t1[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-314a982b0758> in <module>()
# ----> 1 t1[0]
#
# IndexError: tuple index out of range

# %%
t1-(1,2,'a','b')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-b45af8987ec2> in <module>()
# ----> 1 t1-(1,2,'a','b')
#
# TypeError: unsupported operand type(s) for -: 'tuple' and 'tuple'

# %%
t1=(1,2,'a','b')

# %%
t1[0]
# Out:
# 1

# %%
t2=(3,4)

# %%
t1+t2
# Out:
# (1, 2, 'a', 'b', 3, 4)

# %%
t2*3
# Out:
# (3, 4, 3, 4, 3, 4)

# %%
dic={'name':'pey','phone':'0119993323','birth':'1118'}

# %%
a={1:'hi'}

# %%
a={1,'a'}

# %%
a[2]='b'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-ae8215efe5d8> in <module>()
# ----> 1 a[2]='b'
#
# TypeError: 'set' object does not support item assignment

# %%
a={1:'a'}

# %%
a[2]='b'

# %%
a
# Out:
# {1: 'a', 2: 'b'}

# %%
grade={'pey':10,'julliet':99}

# %%
grade['pey']
# Out:
# 10

# %%
a={1:'a',2:'b'}

# %%
a[1]
# Out:
# 'a'

# %%
a={'name':'pey','phone':'0119993323','birth':'1118'}

# %%
a.keys()
# Out:
# dict_keys(['name', 'phone', 'birth'])

# %%
for k in a.keys():
# Out:
#   File "<ipython-input-28-39d83cf3b0b1>", line 1
#     for k in a.keys():
#                       ^
# SyntaxError: unexpected EOF while parsing

# %%
for k in a.keys():
    print(k)
    
    
    phone
    birth
    name
# Out:
# name
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-65b7e8d5d910> in <module>()
#       3
#       4
# ----> 5     phone
#       6     birth
#       7     name
#
# NameError: name 'phone' is not defined

# %%
for k in a.keys():
     print(k)
    
    
    phone
    birth
    name
# Out:
#   File "<ipython-input-30-332cc4bfa548>", line 5
#     phone
#          ^
# IndentationError: unindent does not match any outer indentation level

# %%
for k in a.keys():
     print(k)
    phone
    birth
    name
# Out:
#   File "<ipython-input-31-5371ceffaaa8>", line 3
#     phone
#          ^
# IndentationError: unindent does not match any outer indentation level

# %%
for k in a.keys():
     print(k)
    
phone
birth
name
# Out:
# name
# phone
# birth
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-095cdbb6659a> in <module>()
#       2      print(k)
#       3
# ----> 4 phone
#       5 birth
#       6 name
#
# NameError: name 'phone' is not defined

# %%
for k in a.keys():
     print(k)
    
phone
birth
name
# Out:
# name
# phone
# birth
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-095cdbb6659a> in <module>()
#       2      print(k)
#       3
# ----> 4 phone
#       5 birth
#       6 name
#
# NameError: name 'phone' is not defined

# %%
for k in a.keys():
     print(k)
# Out:
# name
# phone
# birth

# %%
list(a.keys())
# Out:
# ['name', 'phone', 'birth']

# %%
a.values()
# Out:
# dict_values(['pey', '0119993323', '1118'])

# %%
a.items()
# Out:
# dict_items([('name', 'pey'), ('phone', '0119993323'), ('birth', '1118')])

# %%
a.clear()

# %%
a
# Out:
# {}

# %%
a={'name':'pey','phone':'0119993323','birth':'1118'}

# %%
a.get('name')
# Out:
# 'pey'

# %%
'email' in a
# Out:
# False

# %%
s1=set([1,2,3])

# %%
s1
# Out:
# {1, 2, 3}

# %%
s2=set("Hello")

# %%
s2
# Out:
# {'H', 'e', 'l', 'o'}

# %%
s1=set([1,2,3,4,5,6])

# %%
s2=set([4,5,6,7,8,9])

# %%
s1&s2
# Out:
# {4, 5, 6}

# %%
s1.intersection(s2)
# Out:
# {4, 5, 6}

# %%
s1|s2
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
s1=set([1,2,3])

# %%
s1.add(4)

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s1.update(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-70888283393f> in <module>()
# ----> 1 s1.update(5)
#
# TypeError: 'int' object is not iterable

# %%
s1.update([4,5,6,])

# %%
s1
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s1.remove(2)

# %%
sq
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-522ca0bbe691> in <module>()
# ----> 1 sq
#
# NameError: name 'sq' is not defined

# %%
s1
# Out:
# {1, 3, 4, 5, 6}

# %%
a=[1,2,3,4]

# %%
while a:
     a.pop

# %%
while a:
     a.pop

# %%
a=[1,2,3,4]

# %%
while a:
     a.pop()

# %%
if []:

# %%
if []:
     print("True")
    else:
     print("False")

# %%
if [1,2,3]:
     print("True")
    else:
     print("False")

# %%
a=[1,2,3,4]

# %%
while a:
     a.pop()
        
        
4
3
2
1

# %%
if[1,2,3]:
        print("True")
    else:
        print("False")
